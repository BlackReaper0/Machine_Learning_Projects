# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skimpy import skim
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.renderers.default = 'notebook'
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
pd.options.display.max_columns=100
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1=pd.read_csv('Unemployment in India.csv')
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 763                  NaN                                       NaN    NaN
# 764                  NaN                                       NaN    NaN
# 765                  NaN                                       NaN    NaN
# 766                  NaN                                       NaN    NaN
# 767                  NaN                                       NaN    NaN
#
# [768 rows x 7 columns]

# %%
df2=pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
df2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %%
df2_copy=df2.copy()

# %% [markdown]
# #### Here we'll temporarily drop the uncommon features from the df2

# %%
#df2.drop(['Region.1', 'longitude', 'latitude'], axis=1, inplace=True)

# %%
df2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %%
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 763                  NaN                                       NaN    NaN
# 764                  NaN                                       NaN    NaN
# 765                  NaN                                       NaN    NaN
# 766                  NaN                                       NaN    NaN
# 767                  NaN                                       NaN    NaN
#
# [768 rows x 7 columns]

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df=pd.concat([df1, df2], ignore_index=True)
df
# Out:
#               Region         Date  Frequency  \
# 0     Andhra Pradesh   31-05-2019    Monthly
# 1     Andhra Pradesh   30-06-2019    Monthly
# 2     Andhra Pradesh   31-07-2019    Monthly
# 3     Andhra Pradesh   31-08-2019    Monthly
# 4     Andhra Pradesh   30-09-2019    Monthly
# ...              ...          ...        ...
# 1030     West Bengal   30-06-2020          M
# 1031     West Bengal   31-07-2020          M
# 1032     West Bengal   31-08-2020          M
# 1033     West Bengal   30-09-2020          M
# 1034     West Bengal   31-10-2020          M
#
#        Estimated Unemployment Rate (%)   Estimated Employed  \
# 0                                 3.65           11999139.0
# 1                                 3.05           11755881.0
# 2                                 3.75           12086707.0
# 3                                 3.32           12285693.0
# 4                                 5.17           12256762.0
# ...                                ...                  ...
# 1030                              7.29           30726310.0
# 1031                              6.83           35372506.0
# 1032                             14.87           33298644.0
# 1033                              9.35           35707239.0
# 1034                              9.98           33962549.0
#
#        Estimated Labour Participation Rate (%)   Area Region.1  longitude  \
# 0                                        43.24  Rural      NaN        NaN
# 1                                        42.05  Rural      NaN        NaN
# 2                                        43.50  Rural      NaN        NaN
# 3                                        43.97  Rural      NaN        NaN
# 4                                        44.68  Rural      NaN        NaN
# ...                                        ...    ...      ...        ...
# 1030                                     40.39    NaN     East    22.9868
# 1031                                     46.17    NaN     East    22.9868
# 1032                                     47.48    NaN     East    22.9868
# 1033                                     47.73    NaN     East    22.9868
# 1034                                     45.63    NaN     East    22.9868
#
#       latitude
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1030    87.855
# 1031    87.855
# 1032    87.855
# 1033    87.855
# 1034    87.855
#
# [1035 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area', 'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1035   │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 5     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name           ┃ NA   ┃ NA %  ┃ mean    ┃ sd       ┃ p0    ┃ p25     ┃ p75      ┃ p100     ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩  │
# │ │  Estimated            │   28 │  2.71 │      12 │       11 │     0 │     4.7 │       16 │       77 │  █▃▁   │  │
# │ │ Unemployment Rate (%) │      │       │         │          │       │         │          │          │        │  │
# │ │  Estimated Employed   │   28 │  2.71 │ 9000000 │ 10000000 │ 49000 │ 1600000 │ 13000000 │ 59000000 │  █▃▁   │  │
# │ │  Estimated Labour     │   28 │  2.71 │      42 │        8 │    13 │      38 │       45 │       73 │  ▁█▄▁▁ │  │
# │ │ Participation Rate    │      │       │         │          │       │         │          │          │        │  │
# │ │ (%)                   │      │       │         │          │       │         │          │          │        │  │
# │ │ longitude             │  768 │  74.2 │      23 │      6.3 │    11 │      18 │       27 │       34 │ ▄▅▅██▅ │  │
# │ │ latitude              │  768 │  74.2 │      81 │      5.8 │    71 │      76 │       85 │       93 │ ▃██▃▂▃ │  │
# │ └───────────────────────┴──────┴───────┴─────────┴──────────┴───────┴─────────┴──────────┴──────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name              ┃ NA       ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ Region                   │       28 │       2.71 │                          1.3 │                     1295 │  │
# │ │  Date                    │       28 │       2.71 │                          1.3 │                     1295 │  │
# │ │  Frequency               │       28 │       2.71 │                          1.3 │                     1295 │  │
# │ │ Area                     │      295 │       28.5 │                          1.3 │                     1295 │  │
# │ │ Region.1                 │      768 │       74.2 │                          1.3 │                     1295 │  │
# │ └──────────────────────────┴──────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    1007 non-null   object
#  1    Date                                     1007 non-null   object
#  2    Frequency                                1007 non-null   object
#  3    Estimated Unemployment Rate (%)          1007 non-null   float64
#  4    Estimated Employed                       1007 non-null   float64
#  5    Estimated Labour Participation Rate (%)  1007 non-null   float64
#  6   Area                                      740 non-null    object
#  7   Region.1                                  267 non-null    object
#  8   longitude                                 267 non-null    float64
#  9   latitude                                  267 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 81.0+ KB

# %% [markdown]
# ---
# ## 🍀Data Cleaning

# %%
df_g=df.groupby('Region')['Area'].apply(lambda x: x.mode().iloc[0]).reset_index()

# Rename columns
df_g.columns = ['Region', 'Mode_Area']
df_g
# Out:
#               Region Mode_Area
# 0     Andhra Pradesh     Rural
# 1              Assam     Urban
# 2              Bihar     Rural
# 3         Chandigarh     Urban
# 4       Chhattisgarh     Rural
# 5              Delhi     Rural
# 6                Goa     Rural
# 7            Gujarat     Rural
# 8            Haryana     Rural
# 9   Himachal Pradesh     Rural
# 10   Jammu & Kashmir     Rural
# 11         Jharkhand     Rural
# 12         Karnataka     Rural
# 13            Kerala     Rural
# 14    Madhya Pradesh     Rural
# 15       Maharashtra     Rural
# 16         Meghalaya     Rural
# 17            Odisha     Rural
# 18        Puducherry     Urban
# 19            Punjab     Rural
# 20         Rajasthan     Rural
# 21            Sikkim     Urban
# 22        Tamil Nadu     Rural
# 23         Telangana     Rural
# 24           Tripura     Rural
# 25     Uttar Pradesh     Rural
# 26       Uttarakhand     Urban
# 27       West Bengal     Rural

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region     28
# 1                                      Date     28
# 2                                 Frequency     28
# 3           Estimated Unemployment Rate (%)     28
# 4                        Estimated Employed     28
# 5   Estimated Labour Participation Rate (%)     28
# 6                                      Area    295
# 7                                  Region.1    768
# 8                                 longitude    768
# 9                                  latitude    768

# %%
df.loc[df['Region'].isna()]
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 359    NaN   NaN        NaN                               NaN
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
# 754    NaN   NaN        NaN                               NaN
# 755    NaN   NaN        NaN                               NaN
# 756    NaN   NaN        NaN                               NaN
# 757    NaN   NaN        NaN                               NaN
# 758    NaN   NaN        NaN                               NaN
# 759    NaN   NaN        NaN                               NaN
# 760    NaN   NaN        NaN                               NaN
# 761    NaN   NaN        NaN                               NaN
# 762    NaN   NaN        NaN                               NaN
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area  \
# 359                  NaN                                       NaN  NaN
# 360                  NaN                                       NaN  NaN
# 361                  NaN                                       NaN  NaN
# 362                  NaN                                       NaN  NaN
# 363                  NaN                                       NaN  NaN
# 364                  NaN                                       NaN  NaN
# 365                  NaN                                       NaN  NaN
# 366                  NaN                                       NaN  NaN
# 367                  NaN                                       NaN  NaN
# 368                  NaN                                       NaN  NaN
# 369                  NaN                                       NaN  NaN
# 370                  NaN                                       NaN  NaN
# 371                  NaN                                       NaN  NaN
# 372                  NaN                                       NaN  NaN
# 754                  NaN                                       NaN  NaN
# 755                  NaN                                       NaN  NaN
# 756                  NaN                                       NaN  NaN
# 757                  NaN                                       NaN  NaN
# 758                  NaN                                       NaN  NaN
# 759                  NaN                                       NaN  NaN
# 760                  NaN                                       NaN  NaN
# 761                  NaN                                       NaN  NaN
# 762                  NaN                                       NaN  NaN
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN
#
#     Region.1  longitude  latitude
# 359      NaN        NaN       NaN
# 360      NaN        NaN       NaN
# 361      NaN        NaN       NaN
# 362      NaN        NaN       NaN
# 363      NaN        NaN       NaN
# 364      NaN        NaN       NaN
# 365      NaN        NaN       NaN
# 366      NaN        NaN       NaN
# 367      NaN        NaN       NaN
# 368      NaN        NaN       NaN
# 369      NaN        NaN       NaN
# 370      NaN        NaN       NaN
# 371      NaN        NaN       NaN
# 372      NaN        NaN       NaN
# 754      NaN        NaN       NaN
# 755      NaN        NaN       NaN
# 756      NaN        NaN       NaN
# 757      NaN        NaN       NaN
# 758      NaN        NaN       NaN
# 759      NaN        NaN       NaN
# 760      NaN        NaN       NaN
# 761      NaN        NaN       NaN
# 762      NaN        NaN       NaN
# 763      NaN        NaN       NaN
# 764      NaN        NaN       NaN
# 765      NaN        NaN       NaN
# 766      NaN        NaN       NaN
# 767      NaN        NaN       NaN

# %% [markdown]
# #### Here, we can see that all the 28 records are null for each respective feature/attribute. So, it is better to drop these records😉.

# %%
df.dropna(how='all', inplace=True)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area    267
# 7                                  Region.1    740
# 8                                 longitude    740
# 9                                  latitude    740

# %% [markdown]
# ### 🌟Area

# %%
df_c=df.loc[df['Area'].isna(), 'Region'].reset_index()
df_c
# Out:
#      index          Region
# 0      768  Andhra Pradesh
# 1      769  Andhra Pradesh
# 2      770  Andhra Pradesh
# 3      771  Andhra Pradesh
# 4      772  Andhra Pradesh
# ..     ...             ...
# 262   1030     West Bengal
# 263   1031     West Bengal
# 264   1032     West Bengal
# 265   1033     West Bengal
# 266   1034     West Bengal
#
# [267 rows x 2 columns]

# %%
df_c['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df_c['Region'].value_counts().reset_index()
# Out:
#               Region  count
# 0     Andhra Pradesh     10
# 1              Assam     10
# 2        Uttarakhand     10
# 3      Uttar Pradesh     10
# 4            Tripura     10
# 5          Telangana     10
# 6         Tamil Nadu     10
# 7          Rajasthan     10
# 8             Punjab     10
# 9         Puducherry     10
# 10            Odisha     10
# 11         Meghalaya     10
# 12       Maharashtra     10
# 13    Madhya Pradesh     10
# 14            Kerala     10
# 15         Karnataka     10
# 16         Jharkhand     10
# 17  Himachal Pradesh     10
# 18           Haryana     10
# 19           Gujarat     10
# 20               Goa     10
# 21             Delhi     10
# 22      Chhattisgarh     10
# 23             Bihar     10
# 24       West Bengal     10
# 25   Jammu & Kashmir      9
# 26            Sikkim      8

# %%
def fill_area_mode(group):
    mode_value = group['Area'].mode().iloc[0]
    group['Area'].fillna(mode_value, inplace=True)
    return group

df['Area']=df.groupby('Region')['Area'].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1    740
# 8                                 longitude    740
# 9                                  latitude    740

# %% [markdown]
# ### 🌟Region.1

# %%
df['Region.1'].value_counts().reset_index()
# Out:
#     Region.1  count
# 0      North     79
# 1      South     60
# 2       West     50
# 3       East     40
# 4  Northeast     38

# %%
value_counts_df = df['Region.1'].value_counts().reset_index()

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
ax = sns.barplot(x='Region.1', y='count', data=value_counts_df, palette='viridis')
plt.xlabel('Region.1')
plt.ylabel('Frequency')
plt.title('Frequency of Region.1 Values')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility

# Display counts over the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.tight_layout()

# Show the plot
plt.show()

# %%
df.groupby('Region')['Region.1'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
# Out:
#               Region   Region.1
# 0     Andhra Pradesh      South
# 1              Assam  Northeast
# 2              Bihar       East
# 3         Chandigarh       None
# 4       Chhattisgarh       West
# 5              Delhi      North
# 6                Goa       West
# 7            Gujarat       West
# 8            Haryana      North
# 9   Himachal Pradesh      North
# 10   Jammu & Kashmir      North
# 11         Jharkhand       East
# 12         Karnataka      South
# 13            Kerala      South
# 14    Madhya Pradesh       West
# 15       Maharashtra       West
# 16         Meghalaya  Northeast
# 17            Odisha       East
# 18        Puducherry      South
# 19            Punjab      North
# 20         Rajasthan      North
# 21            Sikkim  Northeast
# 22        Tamil Nadu      South
# 23         Telangana      South
# 24           Tripura  Northeast
# 25     Uttar Pradesh      North
# 26       Uttarakhand      North
# 27       West Bengal       East

# %%
def fill_area_mode(group):
    mode_value = group['Region.1'].mode().iloc[0]
    group['Region.1'].fillna(mode_value, inplace=True)
    return group

df['Region.1'] = df.groupby('Region')['Region.1'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1     12
# 8                                 longitude    740
# 9                                  latitude    740

# %%
df[df['Region.1'].isna()]
# Out:
#          Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 415  Chandigarh   31-05-2019    Monthly                             18.35
# 416  Chandigarh   30-06-2019    Monthly                             12.40
# 417  Chandigarh   31-07-2019    Monthly                             21.80
# 418  Chandigarh   31-08-2019    Monthly                              9.52
# 419  Chandigarh   30-09-2019    Monthly                             20.14
# 420  Chandigarh   31-10-2019    Monthly                             13.99
# 421  Chandigarh   30-11-2019    Monthly                             22.05
# 422  Chandigarh   31-12-2019    Monthly                              8.33
# 423  Chandigarh   31-01-2020    Monthly                             20.00
# 424  Chandigarh   29-02-2020    Monthly                             16.67
# 425  Chandigarh   31-03-2020    Monthly                             21.43
# 426  Chandigarh   30-06-2020    Monthly                              7.22
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area  \
# 415             348042.0                                     44.89  Urban
# 416             337145.0                                     40.44  Urban
# 417             294379.0                                     39.47  Urban
# 418             328282.0                                     37.95  Urban
# 419             327239.0                                     42.77  Urban
# 420             330856.0                                     40.06  Urban
# 421             289593.0                                     38.60  Urban
# 422             311146.0                                     35.19  Urban
# 423             332062.0                                     42.94  Urban
# 424             316887.0                                     39.25  Urban
# 425             279839.0                                     36.68  Urban
# 426             306505.0                                     33.80  Urban
#
#     Region.1  longitude  latitude
# 415      NaN        NaN       NaN
# 416      NaN        NaN       NaN
# 417      NaN        NaN       NaN
# 418      NaN        NaN       NaN
# 419      NaN        NaN       NaN
# 420      NaN        NaN       NaN
# 421      NaN        NaN       NaN
# 422      NaN        NaN       NaN
# 423      NaN        NaN       NaN
# 424      NaN        NaN       NaN
# 425      NaN        NaN       NaN
# 426      NaN        NaN       NaN

# %%
df.fillna(value={'Region.1': "Northwest"}, inplace=True)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1      0
# 8                                 longitude    740
# 9                                  latitude    740

# %% [markdown]
# ### 🌟Longitude

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df.groupby('Region')['longitude'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
# Out:
#               Region  longitude
# 0     Andhra Pradesh    15.9129
# 1              Assam    26.2006
# 2              Bihar    25.0961
# 3         Chandigarh        NaN
# 4       Chhattisgarh    21.2787
# 5              Delhi    28.7041
# 6                Goa    15.2993
# 7            Gujarat    22.2587
# 8            Haryana    29.0588
# 9   Himachal Pradesh    31.1048
# 10   Jammu & Kashmir    33.7782
# 11         Jharkhand    23.6102
# 12         Karnataka    15.3173
# 13            Kerala    10.8505
# 14    Madhya Pradesh    22.9734
# 15       Maharashtra    19.7515
# 16         Meghalaya    25.4670
# 17            Odisha    20.9517
# 18        Puducherry    11.9416
# 19            Punjab    31.1471
# 20         Rajasthan    27.0238
# 21            Sikkim    27.5330
# 22        Tamil Nadu    11.1271
# 23         Telangana    18.1124
# 24           Tripura    23.9408
# 25     Uttar Pradesh    26.8467
# 26       Uttarakhand    30.0668
# 27       West Bengal    22.9868

# %%
def fill_area_mode(group):
    mode_value = group['longitude'].mode().iloc[0]
    group['longitude'].fillna(mode_value, inplace=True)
    return group

df['longitude'] = df.groupby('Region')['longitude'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1      0
# 8                                 longitude     12
# 9                                  latitude    740

# %%
df[df['longitude'].isna()]
# Out:
#          Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 415  Chandigarh   31-05-2019    Monthly                             18.35
# 416  Chandigarh   30-06-2019    Monthly                             12.40
# 417  Chandigarh   31-07-2019    Monthly                             21.80
# 418  Chandigarh   31-08-2019    Monthly                              9.52
# 419  Chandigarh   30-09-2019    Monthly                             20.14
# 420  Chandigarh   31-10-2019    Monthly                             13.99
# 421  Chandigarh   30-11-2019    Monthly                             22.05
# 422  Chandigarh   31-12-2019    Monthly                              8.33
# 423  Chandigarh   31-01-2020    Monthly                             20.00
# 424  Chandigarh   29-02-2020    Monthly                             16.67
# 425  Chandigarh   31-03-2020    Monthly                             21.43
# 426  Chandigarh   30-06-2020    Monthly                              7.22
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area  \
# 415             348042.0                                     44.89  Urban
# 416             337145.0                                     40.44  Urban
# 417             294379.0                                     39.47  Urban
# 418             328282.0                                     37.95  Urban
# 419             327239.0                                     42.77  Urban
# 420             330856.0                                     40.06  Urban
# 421             289593.0                                     38.60  Urban
# 422             311146.0                                     35.19  Urban
# 423             332062.0                                     42.94  Urban
# 424             316887.0                                     39.25  Urban
# 425             279839.0                                     36.68  Urban
# 426             306505.0                                     33.80  Urban
#
#       Region.1  longitude  latitude
# 415  Northwest        NaN       NaN
# 416  Northwest        NaN       NaN
# 417  Northwest        NaN       NaN
# 418  Northwest        NaN       NaN
# 419  Northwest        NaN       NaN
# 420  Northwest        NaN       NaN
# 421  Northwest        NaN       NaN
# 422  Northwest        NaN       NaN
# 423  Northwest        NaN       NaN
# 424  Northwest        NaN       NaN
# 425  Northwest        NaN       NaN
# 426  Northwest        NaN       NaN

# %%
df.fillna(value={'longitude': 30.7333}, inplace=True)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1      0
# 8                                 longitude      0
# 9                                  latitude    740

# %% [markdown]
# ### 🌟Latitude

# %%
df.groupby('Region')['latitude'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
# Out:
#               Region  latitude
# 0     Andhra Pradesh   79.7400
# 1              Assam   92.9376
# 2              Bihar   85.3131
# 3         Chandigarh       NaN
# 4       Chhattisgarh   81.8661
# 5              Delhi   77.1025
# 6                Goa   74.1240
# 7            Gujarat   71.1924
# 8            Haryana   76.0856
# 9   Himachal Pradesh   77.1734
# 10   Jammu & Kashmir   76.5762
# 11         Jharkhand   85.2799
# 12         Karnataka   75.7139
# 13            Kerala   76.2711
# 14    Madhya Pradesh   78.6569
# 15       Maharashtra   75.7139
# 16         Meghalaya   91.3662
# 17            Odisha   85.0985
# 18        Puducherry   79.8083
# 19            Punjab   75.3412
# 20         Rajasthan   74.2179
# 21            Sikkim   88.5122
# 22        Tamil Nadu   78.6569
# 23         Telangana   79.0193
# 24           Tripura   91.9882
# 25     Uttar Pradesh   80.9462
# 26       Uttarakhand   79.0193
# 27       West Bengal   87.8550

# %%
def fill_area_mode(group):
    mode_value = group['latitude'].mode().iloc[0]
    group['latitude'].fillna(mode_value, inplace=True)
    return group

df['latitude'] = df.groupby('Region')['latitude'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1      0
# 8                                 longitude      0
# 9                                  latitude     12

# %%
df.fillna(value={'latitude': 76.7794}, inplace=True)

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region      0
# 1                                      Date      0
# 2                                 Frequency      0
# 3           Estimated Unemployment Rate (%)      0
# 4                        Estimated Employed      0
# 5   Estimated Labour Participation Rate (%)      0
# 6                                      Area      0
# 7                                  Region.1      0
# 8                                 longitude      0
# 9                                  latitude      0

# %%
df
# Out:
#               Region         Date  Frequency  \
# 0     Andhra Pradesh   31-05-2019    Monthly
# 1     Andhra Pradesh   30-06-2019    Monthly
# 2     Andhra Pradesh   31-07-2019    Monthly
# 3     Andhra Pradesh   31-08-2019    Monthly
# 4     Andhra Pradesh   30-09-2019    Monthly
# ...              ...          ...        ...
# 1030     West Bengal   30-06-2020          M
# 1031     West Bengal   31-07-2020          M
# 1032     West Bengal   31-08-2020          M
# 1033     West Bengal   30-09-2020          M
# 1034     West Bengal   31-10-2020          M
#
#        Estimated Unemployment Rate (%)   Estimated Employed  \
# 0                                 3.65           11999139.0
# 1                                 3.05           11755881.0
# 2                                 3.75           12086707.0
# 3                                 3.32           12285693.0
# 4                                 5.17           12256762.0
# ...                                ...                  ...
# 1030                              7.29           30726310.0
# 1031                              6.83           35372506.0
# 1032                             14.87           33298644.0
# 1033                              9.35           35707239.0
# 1034                              9.98           33962549.0
#
#        Estimated Labour Participation Rate (%)   Area Region.1  longitude  \
# 0                                        43.24  Rural    South    15.9129
# 1                                        42.05  Rural    South    15.9129
# 2                                        43.50  Rural    South    15.9129
# 3                                        43.97  Rural    South    15.9129
# 4                                        44.68  Rural    South    15.9129
# ...                                        ...    ...      ...        ...
# 1030                                     40.39  Rural     East    22.9868
# 1031                                     46.17  Rural     East    22.9868
# 1032                                     47.48  Rural     East    22.9868
# 1033                                     47.73  Rural     East    22.9868
# 1034                                     45.63  Rural     East    22.9868
#
#       latitude
# 0       79.740
# 1       79.740
# 2       79.740
# 3       79.740
# 4       79.740
# ...        ...
# 1030    87.855
# 1031    87.855
# 1032    87.855
# 1033    87.855
# 1034    87.855
#
# [1007 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1007 entries, 0 to 1034
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    1007 non-null   object
#  1    Date                                     1007 non-null   object
#  2    Frequency                                1007 non-null   object
#  3    Estimated Unemployment Rate (%)          1007 non-null   float64
#  4    Estimated Employed                       1007 non-null   float64
#  5    Estimated Labour Participation Rate (%)  1007 non-null   float64
#  6   Area                                      1007 non-null   object
#  7   Region.1                                  1007 non-null   object
#  8   longitude                                 1007 non-null   float64
#  9   latitude                                  1007 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 86.5+ KB

# %%
df
# Out:
#               Region         Date  Frequency  \
# 0     Andhra Pradesh   31-05-2019    Monthly
# 1     Andhra Pradesh   30-06-2019    Monthly
# 2     Andhra Pradesh   31-07-2019    Monthly
# 3     Andhra Pradesh   31-08-2019    Monthly
# 4     Andhra Pradesh   30-09-2019    Monthly
# ...              ...          ...        ...
# 1030     West Bengal   30-06-2020          M
# 1031     West Bengal   31-07-2020          M
# 1032     West Bengal   31-08-2020          M
# 1033     West Bengal   30-09-2020          M
# 1034     West Bengal   31-10-2020          M
#
#        Estimated Unemployment Rate (%)   Estimated Employed  \
# 0                                 3.65           11999139.0
# 1                                 3.05           11755881.0
# 2                                 3.75           12086707.0
# 3                                 3.32           12285693.0
# 4                                 5.17           12256762.0
# ...                                ...                  ...
# 1030                              7.29           30726310.0
# 1031                              6.83           35372506.0
# 1032                             14.87           33298644.0
# 1033                              9.35           35707239.0
# 1034                              9.98           33962549.0
#
#        Estimated Labour Participation Rate (%)   Area Region.1  longitude  \
# 0                                        43.24  Rural    South    15.9129
# 1                                        42.05  Rural    South    15.9129
# 2                                        43.50  Rural    South    15.9129
# 3                                        43.97  Rural    South    15.9129
# 4                                        44.68  Rural    South    15.9129
# ...                                        ...    ...      ...        ...
# 1030                                     40.39  Rural     East    22.9868
# 1031                                     46.17  Rural     East    22.9868
# 1032                                     47.48  Rural     East    22.9868
# 1033                                     47.73  Rural     East    22.9868
# 1034                                     45.63  Rural     East    22.9868
#
#       latitude
# 0       79.740
# 1       79.740
# 2       79.740
# 3       79.740
# 4       79.740
# ...        ...
# 1030    87.855
# 1031    87.855
# 1032    87.855
# 1033    87.855
# 1034    87.855
#
# [1007 rows x 10 columns]

# %%
df_gm=df.groupby('Region')['Area'].apply(lambda x: x.mode().iloc[0]).reset_index()

df_gm.columns = ['Region', 'Mode_Area']
df_gm
# Out:
#               Region Mode_Area
# 0     Andhra Pradesh     Rural
# 1              Assam     Urban
# 2              Bihar     Rural
# 3         Chandigarh     Urban
# 4       Chhattisgarh     Rural
# 5              Delhi     Rural
# 6                Goa     Rural
# 7            Gujarat     Rural
# 8            Haryana     Rural
# 9   Himachal Pradesh     Rural
# 10   Jammu & Kashmir     Rural
# 11         Jharkhand     Rural
# 12         Karnataka     Rural
# 13            Kerala     Rural
# 14    Madhya Pradesh     Rural
# 15       Maharashtra     Rural
# 16         Meghalaya     Rural
# 17            Odisha     Rural
# 18        Puducherry     Urban
# 19            Punjab     Rural
# 20         Rajasthan     Rural
# 21            Sikkim     Urban
# 22        Tamil Nadu     Rural
# 23         Telangana     Rural
# 24           Tripura     Rural
# 25     Uttar Pradesh     Rural
# 26       Uttarakhand     Urban
# 27       West Bengal     Rural

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.countplot(data=df_gm, x='Mode_Area', palette='viridis')
plt.xlabel('Mode Area')
plt.ylabel('Frequency')
plt.title('Mode Area Distribution by Region')

# Show the plot
plt.show()

# %%
urban_count = df_gm[df_gm['Mode_Area'] == 'Urban']['Region'].count()
rural_count = df_gm[df_gm['Mode_Area'] == 'Rural']['Region'].count()

labels = ['Urban', 'Rural']
values = [urban_count, rural_count]
df_pie = pd.DataFrame({'labels': labels, 'values': values})

fig = px.pie(df_pie, names='labels', values='values', title='Distribution of Urban and Rural Regions')

fig.update_layout(width=800, height=600)
fig.show()

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area', 'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# #### Here, as the column names contain whitespaces, we will remove the whitespaces so that it won't be hectic for us in the further part😄.

# %%
df.rename(columns = {' Date':'Date',
                        ' Frequency': 'Frequency',
                        ' Estimated Unemployment Rate (%)': 'Estimated Unemployment Rate',
                        ' Estimated Employed': 'Estimated Employed',
                        ' Estimated Labour Participation Rate (%)': 'Estimated Labour Participation Rate',
                        'longitude': 'latitude',
                        'latitude': 'longitude',
                        'Region.1': 'Part'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area',
#        'Part', 'latitude', 'longitude'],
#       dtype='object')

# %%
df
# Out:
#               Region         Date Frequency  Estimated Unemployment Rate  \
# 0     Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1     Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2     Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3     Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4     Andhra Pradesh   30-09-2019   Monthly                         5.17
# ...              ...          ...       ...                          ...
# 1030     West Bengal   30-06-2020         M                         7.29
# 1031     West Bengal   31-07-2020         M                         6.83
# 1032     West Bengal   31-08-2020         M                        14.87
# 1033     West Bengal   30-09-2020         M                         9.35
# 1034     West Bengal   31-10-2020         M                         9.98
#
#       Estimated Employed  Estimated Labour Participation Rate   Area   Part  \
# 0             11999139.0                                43.24  Rural  South
# 1             11755881.0                                42.05  Rural  South
# 2             12086707.0                                43.50  Rural  South
# 3             12285693.0                                43.97  Rural  South
# 4             12256762.0                                44.68  Rural  South
# ...                  ...                                  ...    ...    ...
# 1030          30726310.0                                40.39  Rural   East
# 1031          35372506.0                                46.17  Rural   East
# 1032          33298644.0                                47.48  Rural   East
# 1033          35707239.0                                47.73  Rural   East
# 1034          33962549.0                                45.63  Rural   East
#
#       latitude  longitude
# 0      15.9129     79.740
# 1      15.9129     79.740
# 2      15.9129     79.740
# 3      15.9129     79.740
# 4      15.9129     79.740
# ...        ...        ...
# 1030   22.9868     87.855
# 1031   22.9868     87.855
# 1032   22.9868     87.855
# 1033   22.9868     87.855
# 1034   22.9868     87.855
#
# [1007 rows x 10 columns]

# %% [markdown]
# ### 🍁Checking each Feature

# %% [markdown]
# ### 🌟Region

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df['Region'].value_counts().reset_index().sort_values(by='count', ascending=False)
# Out:
#               Region  count
# 0     Andhra Pradesh     38
# 11       Maharashtra     38
# 19             Bihar     38
# 18      Chhattisgarh     38
# 17             Delhi     38
# 16           Gujarat     38
# 15           Haryana     38
# 1             Kerala     38
# 13         Jharkhand     38
# 12         Karnataka     38
# 14  Himachal Pradesh     38
# 10    Madhya Pradesh     38
# 5          Telangana     38
# 9             Odisha     38
# 3      Uttar Pradesh     38
# 4            Tripura     38
# 2        West Bengal     38
# 6         Tamil Nadu     38
# 7          Rajasthan     38
# 8             Punjab     38
# 20         Meghalaya     37
# 21       Uttarakhand     37
# 22             Assam     36
# 23        Puducherry     36
# 24               Goa     34
# 25   Jammu & Kashmir     30
# 26            Sikkim     25
# 27        Chandigarh     12

# %% [markdown]
# ### 🌟Date

# %%
df['Date'].unique()
# Out:
# array([' 31-05-2019', ' 30-06-2019', ' 31-07-2019', ' 31-08-2019',
#        ' 30-09-2019', ' 31-10-2019', ' 30-11-2019', ' 31-12-2019',
#        ' 31-01-2020', ' 29-02-2020', ' 31-03-2020', ' 30-04-2020',
#        ' 31-05-2020', ' 30-06-2020', ' 31-07-2020', ' 31-08-2020',
#        ' 30-09-2020', ' 31-10-2020'], dtype=object)

# %% [markdown]
# ##### Now this is a problem, cause there is a whitespace before every value, which would definitely throw us an error while converting this feature to `datetime`. So, here we'll remove the whitespaces 😒.

# %%
df['Date']=df['Date'].str.replace(' ','')

# %%
df['Date'].unique()
# Out:
# array(['31-05-2019', '30-06-2019', '31-07-2019', '31-08-2019',
#        '30-09-2019', '31-10-2019', '30-11-2019', '31-12-2019',
#        '31-01-2020', '29-02-2020', '31-03-2020', '30-04-2020',
#        '31-05-2020', '30-06-2020', '31-07-2020', '31-08-2020',
#        '30-09-2020', '31-10-2020'], dtype=object)

# %% [markdown]
# ### 🌟Frequency

# %%
df['Frequency'].unique()
# Out:
# array([' Monthly', 'Monthly', ' M'], dtype=object)

# %% [markdown]
# ##### No explaination needed 😂😂.

# %%
df['Frequency']=df['Frequency'].str.replace(' Monthly', 'Monthly')
df['Frequency']=df['Frequency'].str.replace(' M', 'Monthly')

# %%
df['Frequency'].unique()
# Out:
# array(['Monthly'], dtype=object)

# %% [markdown]
# ### 🌟Area

# %%
df['Area'].unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %% [markdown]
# ### 🌟Part

# %%
df['Part'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North', 'Northwest'],
#       dtype=object)

# %%
df.to_csv('Unemployment_combined.csv', index=False)

# %% [markdown]
# #### OK!! we are done with the cleaning process 🥳🥳

# %% [markdown]
# ---
# ## 🍀Data Formating

# %%
df
# Out:
#               Region        Date Frequency  Estimated Unemployment Rate  \
# 0     Andhra Pradesh  31-05-2019   Monthly                         3.65
# 1     Andhra Pradesh  30-06-2019   Monthly                         3.05
# 2     Andhra Pradesh  31-07-2019   Monthly                         3.75
# 3     Andhra Pradesh  31-08-2019   Monthly                         3.32
# 4     Andhra Pradesh  30-09-2019   Monthly                         5.17
# ...              ...         ...       ...                          ...
# 1030     West Bengal  30-06-2020   Monthly                         7.29
# 1031     West Bengal  31-07-2020   Monthly                         6.83
# 1032     West Bengal  31-08-2020   Monthly                        14.87
# 1033     West Bengal  30-09-2020   Monthly                         9.35
# 1034     West Bengal  31-10-2020   Monthly                         9.98
#
#       Estimated Employed  Estimated Labour Participation Rate   Area   Part  \
# 0             11999139.0                                43.24  Rural  South
# 1             11755881.0                                42.05  Rural  South
# 2             12086707.0                                43.50  Rural  South
# 3             12285693.0                                43.97  Rural  South
# 4             12256762.0                                44.68  Rural  South
# ...                  ...                                  ...    ...    ...
# 1030          30726310.0                                40.39  Rural   East
# 1031          35372506.0                                46.17  Rural   East
# 1032          33298644.0                                47.48  Rural   East
# 1033          35707239.0                                47.73  Rural   East
# 1034          33962549.0                                45.63  Rural   East
#
#       latitude  longitude
# 0      15.9129     79.740
# 1      15.9129     79.740
# 2      15.9129     79.740
# 3      15.9129     79.740
# 4      15.9129     79.740
# ...        ...        ...
# 1030   22.9868     87.855
# 1031   22.9868     87.855
# 1032   22.9868     87.855
# 1033   22.9868     87.855
# 1034   22.9868     87.855
#
# [1007 rows x 10 columns]

# %%
df['Date'].unique()
# Out:
# array(['31-05-2019', '30-06-2019', '31-07-2019', '31-08-2019',
#        '30-09-2019', '31-10-2019', '30-11-2019', '31-12-2019',
#        '31-01-2020', '29-02-2020', '31-03-2020', '30-04-2020',
#        '31-05-2020', '30-06-2020', '31-07-2020', '31-08-2020',
#        '30-09-2020', '31-10-2020'], dtype=object)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#               Region       Date Frequency  Estimated Unemployment Rate  \
# 0     Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1     Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2     Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3     Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4     Andhra Pradesh 2019-09-30   Monthly                         5.17
# ...              ...        ...       ...                          ...
# 1030     West Bengal 2020-06-30   Monthly                         7.29
# 1031     West Bengal 2020-07-31   Monthly                         6.83
# 1032     West Bengal 2020-08-31   Monthly                        14.87
# 1033     West Bengal 2020-09-30   Monthly                         9.35
# 1034     West Bengal 2020-10-31   Monthly                         9.98
#
#       Estimated Employed  Estimated Labour Participation Rate   Area   Part  \
# 0             11999139.0                                43.24  Rural  South
# 1             11755881.0                                42.05  Rural  South
# 2             12086707.0                                43.50  Rural  South
# 3             12285693.0                                43.97  Rural  South
# 4             12256762.0                                44.68  Rural  South
# ...                  ...                                  ...    ...    ...
# 1030          30726310.0                                40.39  Rural   East
# 1031          35372506.0                                46.17  Rural   East
# 1032          33298644.0                                47.48  Rural   East
# 1033          35707239.0                                47.73  Rural   East
# 1034          33962549.0                                45.63  Rural   East
#
#       latitude  longitude  Year  Month
# 0      15.9129     79.740  2019      5
# 1      15.9129     79.740  2019      6
# 2      15.9129     79.740  2019      7
# 3      15.9129     79.740  2019      8
# 4      15.9129     79.740  2019      9
# ...        ...        ...   ...    ...
# 1030   22.9868     87.855  2020      6
# 1031   22.9868     87.855  2020      7
# 1032   22.9868     87.855  2020      8
# 1033   22.9868     87.855  2020      9
# 1034   22.9868     87.855  2020     10
#
# [1007 rows x 12 columns]

# %%
import calendar
df['Month'] = df['Date'].dt.month.apply(lambda x: calendar.month_name[x])

# %%
df
# Out:
#               Region       Date Frequency  Estimated Unemployment Rate  \
# 0     Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1     Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2     Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3     Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4     Andhra Pradesh 2019-09-30   Monthly                         5.17
# ...              ...        ...       ...                          ...
# 1030     West Bengal 2020-06-30   Monthly                         7.29
# 1031     West Bengal 2020-07-31   Monthly                         6.83
# 1032     West Bengal 2020-08-31   Monthly                        14.87
# 1033     West Bengal 2020-09-30   Monthly                         9.35
# 1034     West Bengal 2020-10-31   Monthly                         9.98
#
#       Estimated Employed  Estimated Labour Participation Rate   Area   Part  \
# 0             11999139.0                                43.24  Rural  South
# 1             11755881.0                                42.05  Rural  South
# 2             12086707.0                                43.50  Rural  South
# 3             12285693.0                                43.97  Rural  South
# 4             12256762.0                                44.68  Rural  South
# ...                  ...                                  ...    ...    ...
# 1030          30726310.0                                40.39  Rural   East
# 1031          35372506.0                                46.17  Rural   East
# 1032          33298644.0                                47.48  Rural   East
# 1033          35707239.0                                47.73  Rural   East
# 1034          33962549.0                                45.63  Rural   East
#
#       latitude  longitude  Year      Month
# 0      15.9129     79.740  2019        May
# 1      15.9129     79.740  2019       June
# 2      15.9129     79.740  2019       July
# 3      15.9129     79.740  2019     August
# 4      15.9129     79.740  2019  September
# ...        ...        ...   ...        ...
# 1030   22.9868     87.855  2020       June
# 1031   22.9868     87.855  2020       July
# 1032   22.9868     87.855  2020     August
# 1033   22.9868     87.855  2020  September
# 1034   22.9868     87.855  2020    October
#
# [1007 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area',
#        'Part', 'latitude', 'longitude', 'Year', 'Month'],
#       dtype='object')

# %% [markdown]
# ---
# ## 🍀Data Visualization

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])
corr = numeric_columns.corr()

plt.figure(figsize=(10, 8))

sns.heatmap(corr, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), fmt=".2f", linewidths=0.5)

plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df_2019 = df[df['Year'] == 2019]
month_order = [calendar.month_name[i] for i in range(1, 13)]
df_2019['Month'] = pd.Categorical(df_2019['Month'], categories=month_order, ordered=True)


df_2019_monthly_avg = df_2019.groupby('Month')['Estimated Unemployment Rate'].mean().reset_index()

fig_2019 = px.line(df_2019_monthly_avg, x='Month', y='Estimated Unemployment Rate', title='Unemployment Rate Trend (2019)',
                   labels={'Estimated Unemployment Rate': 'Unemployment Rate (%)'},
                   line_dash_sequence=['solid'], color_discrete_sequence=['blue'])

trace_2019 = go.Scatter(x=df_2019_monthly_avg['Month'], y=df_2019_monthly_avg['Estimated Unemployment Rate'], 
                        mode='markers+lines', name='2019', line=dict(color='blue'))

fig_2019.add_trace(trace_2019)
fig_2019.update_layout(
    xaxis_title='Month',
    yaxis_title='Unemployment Rate (%)',
    template='plotly_white'
)

fig_2019.show()

# %%
df_2020 = df[df['Year'] == 2020]
month_order = [calendar.month_name[i] for i in range(1, 13)]
df_2020['Month'] = pd.Categorical(df_2020['Month'], categories=month_order, ordered=True)

df_2020_monthly_avg = df_2020.groupby('Month')['Estimated Unemployment Rate'].mean().reset_index()


fig_2020 = px.line(df_2020_monthly_avg, x='Month', y='Estimated Unemployment Rate', title='Unemployment Rate Trend (2020)',
                   labels={'Estimated Unemployment Rate': 'Unemployment Rate (%)'},
                   line_dash_sequence=['solid'], color_discrete_sequence=['red'])

trace_2020 = go.Scatter(x=df_2020_monthly_avg['Month'], y=df_2020_monthly_avg['Estimated Unemployment Rate'], 
                        mode='markers+lines', name='2020', line=dict(color='red'))

fig_2020.add_trace(trace_2020)
fig_2020.update_layout(
    xaxis_title='Month',
    yaxis_title='Unemployment Rate (%)',
    template='plotly_white'
)

fig_2020.show()

# %%
df_2019 = df[df['Year'] == 2019]
df_2020 = df[df['Year'] == 2020]

avg_unemployment_2019 = df_2019.groupby('Region')['Estimated Unemployment Rate'].mean().reset_index()
avg_unemployment_2020 = df_2020.groupby('Region')['Estimated Unemployment Rate'].mean().reset_index()

combined_df = pd.merge(avg_unemployment_2019, avg_unemployment_2020, on='Region', suffixes=('_2019', '_2020'))

fig = px.bar(combined_df, x='Region', y=['Estimated Unemployment Rate_2019', 'Estimated Unemployment Rate_2020'],
             barmode='group', labels={'value': 'Unemployment Rate (%)'},
             title='Average Estimated Unemployment Rate by Region (2019 vs. 2020)')

fig.update_layout(
    xaxis_title='Region',
    yaxis_title='Unemployment Rate (%)',
    template='plotly_white'
)

fig.show()

# %%
df_2019 = df[df['Year'] == 2019]
month_order = [calendar.month_name[i] for i in range(1, 13)]
df_2019['Month'] = pd.Categorical(df_2019['Month'], categories=month_order, ordered=True)

df_2019_monthly_avg = df_2019.groupby('Month')['Estimated Labour Participation Rate'].mean().reset_index()

fig_2019 = px.line(df_2019_monthly_avg, x='Month', y='Estimated Labour Participation Rate', 
                   title='Labour Participation Rate Trend (2019)',
                   labels={'Estimated Labour Participation Rate': 'Labour Participation Rate (%)'},
                   line_dash_sequence=['solid'], color_discrete_sequence=['blue'])

trace_2019 = go.Scatter(x=df_2019_monthly_avg['Month'], y=df_2019_monthly_avg['Estimated Labour Participation Rate'], 
                        mode='markers+lines', name='2019', line=dict(color='blue'))

fig_2019.add_trace(trace_2019)
fig_2019.update_layout(
    xaxis_title='Month',
    yaxis_title='Labour Participation Rate (%)',
    template='plotly_white'
)

fig_2019.show()

# %%
df_2020 = df[df['Year'] == 2020]
month_order = [calendar.month_name[i] for i in range(1, 13)]
df_2020['Month'] = pd.Categorical(df_2020['Month'], categories=month_order, ordered=True)

df_2020_monthly_avg = df_2020.groupby('Month')['Estimated Labour Participation Rate'].mean().reset_index()

fig_2020 = px.line(df_2020_monthly_avg, x='Month', y='Estimated Labour Participation Rate', 
                   title='Labour Participation Rate Trend (2020)',
                   labels={'Estimated Labour Participation Rate': 'Labour Participation Rate (%)'},
                   line_dash_sequence=['solid'], color_discrete_sequence=['red'])

trace_2020 = go.Scatter(x=df_2020_monthly_avg['Month'], y=df_2020_monthly_avg['Estimated Labour Participation Rate'], 
                        mode='markers+lines', name='2020', line=dict(color='red'))

fig_2020.add_trace(trace_2020)
fig_2020.update_layout(
    xaxis_title='Month',
    yaxis_title='Labour Participation Rate (%)',
    template='plotly_white'
)

fig_2020.show()

# %%
df_2019 = df[df['Year'] == 2019]
df_2020 = df[df['Year'] == 2020]

avg_labpart_2019 = df_2019.groupby('Region')['Estimated Labour Participation Rate'].mean().reset_index()
avg_labpart_2020 = df_2020.groupby('Region')['Estimated Labour Participation Rate'].mean().reset_index()

combined_df = pd.merge(avg_labpart_2019, avg_labpart_2020, on='Region', suffixes=('_2019', '_2020'))

fig = px.bar(combined_df, x='Region', y=['Estimated Labour Participation Rate_2019', 'Estimated Labour Participation Rate_2020'],
             barmode='group', labels={'value': 'Participation Rate (%)'},
             title='Average Estimated Labour Paricipation Rate by Region (2019 vs. 2020)')

fig.update_layout(
    xaxis_title='Region',
    yaxis_title='Participation Rate (%)',
    template='plotly_white'
)

fig.show()

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

df['Month'] = pd.Categorical(df['Month'], categories=month_order, ordered=True)
df_2019 = df[df['Year'] == 2019]
df_2020 = df[df['Year'] == 2020]

avg_unemployment_2019 = df_2019.groupby(['Month', 'Area'])['Estimated Unemployment Rate'].mean().reset_index()
avg_unemployment_2020 = df_2020.groupby(['Month', 'Area'])['Estimated Unemployment Rate'].mean().reset_index()

avg_unemployment_2019['Year'] = 2019
avg_unemployment_2020['Year'] = 2020

combined_df = pd.concat([avg_unemployment_2019, avg_unemployment_2020], ignore_index=True)

fig = px.bar(combined_df, x='Month', y='Estimated Unemployment Rate', color='Area', facet_col='Year',
             labels={'Estimated Unemployment Rate': 'Unemployment Rate (%)'},
             title='Unemployment Rate Comparison (2019 vs. 2020) by Area',
             color_discrete_map={'Rural': 'blue', 'Urban': 'red'})

fig.update_layout(
    xaxis_title='Month',
    yaxis_title='Unemployment Rate (%)',
    template='plotly_white'
)

fig.show()

# %%
fig = px.scatter_geo(df, 
                     lat='latitude', 
                     lon='longitude', 
                     color='Region',
                     hover_name='Part',
                     size='Estimated Unemployment Rate',
                     animation_frame='Month',
                     scope='asia',
                     template='seaborn',
                     title='Impact of lockdown on Employment across regions')

fig.update_geos(lataxis_range=[5, 35], lonaxis_range=[65, 100], oceancolor="#3399FF", showocean=True)

fig.update_layout(width=1000, height=800)

fig.show()

# %%
df_2019 = df[df['Year'] == 2019]
df_2020 = df[df['Year'] == 2020]

avg_unemployment_2019 = df_2019.groupby('Region')['Estimated Labour Participation Rate'].mean().reset_index()
avg_unemployment_2020 = df_2020.groupby('Region')['Estimated Labour Participation Rate'].mean().reset_index()

comparison_df = avg_unemployment_2019.merge(avg_unemployment_2020, on='Region', suffixes=('_2019', '_2020'))

comparison_df = comparison_df.rename(columns={'Estimated Labour Participation Rate_2019': 'Avg Labour Participation Rate 2019',
                                              'Estimated Labour Participation Rate_2020': 'Avg Labour Participation Rate 2020'})
comparison_df
# Out:
#               Region  Avg Labour Participation Rate 2019  \
# 0     Andhra Pradesh                           40.095000
# 1              Assam                           46.140667
# 2              Bihar                           38.625000
# 3         Chandigarh                           39.921250
# 4       Chhattisgarh                           44.908750
# 5              Delhi                           41.438750
# 6                Goa                           39.686250
# 7            Gujarat                           47.681875
# 8            Haryana                           43.208125
# 9   Himachal Pradesh                           46.945625
# 10   Jammu & Kashmir                           43.017500
# 11         Jharkhand                           42.113125
# 12         Karnataka                           40.334375
# 13            Kerala                           36.848750
# 14    Madhya Pradesh                           39.540000
# 15       Maharashtra                           43.824375
# 16         Meghalaya                           58.116250
# 17            Odisha                           41.030000
# 18        Puducherry                           39.968750
# 19            Punjab                           42.912500
# 20         Rajasthan                           40.566875
# 21            Sikkim                           48.460000
# 22        Tamil Nadu                           44.487500
# 23         Telangana                           54.435000
# 24           Tripura                           63.190000
# 25     Uttar Pradesh                           39.750625
# 26       Uttarakhand                           34.040625
# 27       West Bengal                           46.887500
#
#     Avg Labour Participation Rate 2020
# 0                            38.664545
# 1                            43.307143
# 2                            37.365455
# 3                            38.167500
# 4                            40.535000
# 5                            35.708182
# 6                            38.857222
# 7                            44.673636
# 8                            42.105000
# 9                            40.436818
# 10                           38.138333
# 11                           40.751364
# 12                           42.378182
# 13                           32.751818
# 14                           38.346364
# 15                           40.816364
# 16                           57.614762
# 17                           36.860909
# 18                           36.674500
# 19                           39.320909
# 20                           39.822273
# 21                           44.012857
# 22                           36.656818
# 23                           52.855909
# 24                           59.023182
# 25                           38.371818
# 26                           34.280000
# 27                           44.230455

# %%
x = np.arange(len(comparison_df['Region']))
width = 0.4
plt.figure(figsize=(10, 6))

plt.bar(x - width/2, comparison_df['Avg Labour Participation Rate 2019'], width, label='2019', color='cyan')
plt.bar(x + width/2, comparison_df['Avg Labour Participation Rate 2020'], width, label='2020', color='blueviolet')

plt.xlabel('Region')
plt.ylabel('Average Estimated Labour Participation Rate')
plt.title('Comparison of Labour Participation Rates (2019 vs 2020) by Region')
plt.xticks(x, comparison_df['Region'], rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
df_2019 = df[df['Year'] == 2019]
df_2020 = df[df['Year'] == 2020]

avg_unemployment_2019 = df_2019.groupby('Region')['Estimated Unemployment Rate'].mean().reset_index()
avg_unemployment_2020 = df_2020.groupby('Region')['Estimated Unemployment Rate'].mean().reset_index()

comparison_df = avg_unemployment_2019.merge(avg_unemployment_2020, on='Region', suffixes=('_2019', '_2020'))

comparison_df = comparison_df.rename(columns={'Estimated Unemployment Rate_2019': 'Avg Unemployment Rate 2019',
                                              'Estimated Unemployment Rate_2020': 'Avg Unemployment Rate 2020'})
comparison_df
# Out:
#               Region  Avg Unemployment Rate 2019  Avg Unemployment Rate 2020
# 0     Andhra Pradesh                    4.826875                    9.944091
# 1              Assam                    6.420667                    5.684762
# 2              Bihar                   13.882500                   22.831818
# 3         Chandigarh                   15.822500                   16.330000
# 4       Chhattisgarh                    7.346875                    9.971364
# 5              Delhi                   13.750625                   19.363636
# 6                Goa                    9.346250                   10.817222
# 7            Gujarat                    4.979375                    7.758182
# 8            Haryana                   22.798750                   29.360000
# 9   Himachal Pradesh                   19.064375                   17.034091
# 10   Jammu & Kashmir                   16.141667                   16.364444
# 11         Jharkhand                   14.233750                   24.728636
# 12         Karnataka                    3.238750                    9.626818
# 13            Kerala                    7.131250                   11.986818
# 14    Madhya Pradesh                    4.788125                    9.059545
# 15       Maharashtra                    5.459375                    9.275000
# 16         Meghalaya                    4.012500                    4.953810
# 17            Odisha                    3.661250                    7.475455
# 18        Puducherry                    1.699375                   20.891000
# 19            Punjab                   10.882500                   12.843636
# 20         Rajasthan                   12.301250                   16.158636
# 21            Sikkim                    6.257273                    9.482143
# 22        Tamil Nadu                    3.063750                   15.127727
# 23         Telangana                    4.115625                    9.960909
# 24           Tripura                   28.363125                   26.843182
# 25     Uttar Pradesh                   10.888125                   12.481818
# 26       Uttarakhand                    5.800625                    9.356667
# 27       West Bengal                    6.625625                   10.154545

# %%
x = np.arange(len(comparison_df['Region']))
width = 0.4
plt.figure(figsize=(10, 6))

plt.bar(x - width/2, comparison_df['Avg Unemployment Rate 2019'], width, label='2019', color='blue')
plt.bar(x + width/2, comparison_df['Avg Unemployment Rate 2020'], width, label='2020', color='orange')

plt.xlabel('Region')
plt.ylabel('Average Estimated Unemployment Rate')
plt.title('Comparison of Unemployment Rates (2019 vs 2020) by Region')
plt.xticks(x, comparison_df['Region'], rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
comparison_df['Unemployment Rate Difference'] = comparison_df['Avg Unemployment Rate 2020'] - comparison_df['Avg Unemployment Rate 2019']
most_impacted_region = comparison_df.loc[comparison_df['Unemployment Rate Difference'].idxmax()]

most_impacted_df = pd.DataFrame({
    'Region': [most_impacted_region['Region']],
    'Avg Unemployment Rate 2019': [most_impacted_region['Avg Unemployment Rate 2019']],
    'Avg Unemployment Rate 2020': [most_impacted_region['Avg Unemployment Rate 2020']],
    'Unemployment Rate Difference': [most_impacted_region['Unemployment Rate Difference']]
})
most_impacted_df
# Out:
#        Region  Avg Unemployment Rate 2019  Avg Unemployment Rate 2020  \
# 0  Puducherry                    1.699375                      20.891
#
#    Unemployment Rate Difference
# 0                     19.191625

# %% [markdown]
# ---
# ### 🍁Conclusion

# %% [markdown]
# #### The State `Puduchery` had the maximum impact among all other States 🤓.
